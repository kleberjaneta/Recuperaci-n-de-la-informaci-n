# %% [markdown]
# # Web Scraping

# %% [markdown]
# Web Scraping para la obtencion de un corpus y creación de un sistema de recuperación.

# %% [markdown]
# ### Obtención del Corpus

# %% [markdown]
# La página objetivo para el scraping es "allrecipes.com" Una página que contiene una gran variedad de contenido sobre recetas de cocina.

# %% [markdown]
# Para el scraping utilizaremos las librerias requests y Beautifulsoup. Requests permite realizar solicitudes HTTP  y Beautifulsoup permite obtener datos de documentos HTML y XML.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Se especifica la url de la página a la cual se va a realizar el scraping

# %%
url_base = "https://www.allrecipes.com/ingredients-a-z-6740416#alphabetical-list-a"

# %% [markdown]
# Los headers(encabezados) proporcionan información adicional al servidor sobre la solicitud HTTP que se realiza al servidor para obtener el contenido de la página. User-Agent especifica información sobre el cliente que esta haciendo la solicitud. En este caso se especifica que es un navegador.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
#Solicitud a la pagina objetivo
response_base = requests.get(url_base, headers=headers)

#Verificación de si la solicitud fue exitosa
if response_base.status_code == 200:
    print("Solicitud exitosa")
else:
    print(f"Error en la solicitud: {response_base.status_code}")
# Out:
# Solicitud exitosa

# %%
#Obtencion del contenido del HTML de la pagina objetivo
soup_base = BeautifulSoup(response_base.content, 'html.parser')

# %% [markdown]
# Para obtener los datos por medio de Beautifulsoup se debe realizar una inspeccion previa al HTML de la pagina objetivo e identificar las etiquetas en las cuales se encuentran los datos que queremos obtener.

# %%
#Listas para almacenar la información que vamos a extraer
lista_urls = []
lista_titulos = []
lista_descripcion = []
lista_ingredientes = []
lista_pasos = []
lista_categorias = []

# %%
#Extracción de los urls de recetas por categorias(pastel, pollo,sopa)
urls_categorias = soup_base.select('.loc.mntl-link-list li a')
#Se recorre cada categoria
for url in urls_categorias:
    #Se obtiene la url de cada categoria
    url_categoria = url.get('href')
    categoria = url.get_text(strip=True)
    #Se realiza la solicitud a la pagina categoria
    response_categoria = requests.get(url_categoria, headers=headers)
    #Se obtiene el contenido de la url de la categoria que contiene varias recetas
    soup_categoria = BeautifulSoup(response_categoria.content, 'html.parser')
    #Extraccion de las urls de recetas en la categoria
    urls_recetas = soup_categoria.select('#mntl-taxonomysc-article-list-group_1-0 div div a')

    #Se recorre cada receta
    for url in urls_recetas:
        #Se obtiene la url de cada receta
        url_receta = url.get('href')
        #Se realiza la solicitud a la pagina receta
        response_receta = requests.get(url_receta, headers=headers)
        #Se obtiene el contenido de la url de la receta 
        soup_receta = BeautifulSoup(response_receta.content, 'html.parser')

        #Extraemos la información que necesitamos
        titulo = soup_receta.select_one('.article-heading.text-headline-400')
        if titulo:
            lista_titulos.append(titulo.get_text(strip=True))
        else:
            lista_titulos.append("No Disponible")

        descripcion = soup_receta.select_one('.article-subheading.text-body-100')
        if descripcion:            
            lista_descripcion.append(descripcion.get_text(strip=True))
        else:
            lista_descripcion.append("No Disponible")
        
        info_ingredientes = soup_receta.select('.mm-recipes-structured-ingredients__list li p')
        ingredientes = ""
        if info_ingredientes:
            for info in info_ingredientes:
                ingredientes = ingredientes + info.get_text(strip=True) + " "
            lista_ingredientes.append(ingredientes)
        else:
            lista_ingredientes.append("No Disponible")
        
        info_pasos = soup_receta.select('#mntl-sc-block_1-0 li p')
        pasos = ""
        if info_pasos:
            for info in info_pasos:
                pasos = pasos + info.get_text(strip=True)+" "
            lista_pasos.append(pasos)
        else:
            lista_pasos.append("No Disponible")        

        lista_urls.append(url_receta)
        lista_categorias.append(categoria)

    #Para saber si estamos extrayendo la informacion imprimiremos el tamaño de cada lista 
    print(f" Categoria: {len(lista_categorias)} Titulo:{len(lista_titulos)} Descripcion:{len(lista_descripcion)} Ingredientes:{len(lista_ingredientes)} Pasos:{len(lista_pasos)} Urls:{len(lista_urls)} ")
# Out:
#  Categoria: 64 Titulo:64 Descripcion:64 Ingredientes:64 Pasos:64 Urls:64
#  Categoria: 128 Titulo:128 Descripcion:128 Ingredientes:128 Pasos:128 Urls:128
#  Categoria: 133 Titulo:133 Descripcion:133 Ingredientes:133 Pasos:133 Urls:133
#  Categoria: 197 Titulo:197 Descripcion:197 Ingredientes:197 Pasos:197 Urls:197
#  Categoria: 261 Titulo:261 Descripcion:261 Ingredientes:261 Pasos:261 Urls:261
#  Categoria: 325 Titulo:325 Descripcion:325 Ingredientes:325 Pasos:325 Urls:325
#  Categoria: 389 Titulo:389 Descripcion:389 Ingredientes:389 Pasos:389 Urls:389
#  Categoria: 453 Titulo:453 Descripcion:453 Ingredientes:453 Pasos:453 Urls:453
#  Categoria: 517 Titulo:517 Descripcion:517 Ingredientes:517 Pasos:517 Urls:517
#  Categoria: 581 Titulo:581 Descripcion:581 Ingredientes:581 Pasos:581 Urls:581
#  Categoria: 645 Titulo:645 Descripcion:645 Ingredientes:645 Pasos:645 Urls:645
#  Categoria: 709 Titulo:709 Descripcion:709 Ingredientes:709 Pasos:709 Urls:709
#  Categoria: 773 Titulo:773 Descripcion:773 Ingredientes:773 Pasos:773 Urls:773
#  Categoria: 837 Titulo:837 Descripcion:837 Ingredientes:837 Pasos:837 Urls:837
#  Categoria: 877 Titulo:877 Descripcion:877 Ingredientes:877 Pasos:877 Urls:877
#  Categoria: 895 Titulo:895 Descripcion:895 Ingredientes:895 Pasos:895 Urls:895
#  Categoria: 959 Titulo:959 Descripcion:959 Ingredientes:959 Pasos:959 Urls:959
#  Categoria: 1023 Titulo:1023 Descripcion:1023 Ingredientes:1023 Pasos:1023 Urls:1023
#  Categoria: 1087 Titulo:1087 Descripcion:1087 Ingredientes:1087 Pasos:1087 Urls:1087
#  Categoria: 1151 Titulo:1151 Descripcion:1151 Ingredientes:1151 Pasos:1151 Urls:1151
#  Categoria: 1215 Titulo:1215 Descripcion:1215 Ingredientes:1215 Pasos:1215 Urls:1215
#  Categoria: 1279 Titulo:1279 Descripcion:1279 Ingredientes:1279 Pasos:1279 Urls:1279
#  Categoria: 1343 Titulo:1343 Descripcion:1343 Ingredientes:1343 Pasos:1343 Urls:1343
#  Categoria: 1407 Titulo:1407 Descripcion:1407 Ingredientes:1407 Pasos:1407 Urls:1407
#  Categoria: 1471 Titulo:1471 Descripcion:1471 Ingredientes:1471 Pasos:1471 Urls:1471
#  Categoria: 1535 Titulo:1535 Descripcion:1535 Ingredientes:1535 Pasos:1535 Urls:1535
#  Categoria: 1599 Titulo:1599 Descripcion:1599 Ingredientes:1599 Pasos:1599 Urls:1599
#  Categoria: 1621 Titulo:1621 Descripcion:1621 Ingredientes:1621 Pasos:1621 Urls:1621
#  Categoria: 1685 Titulo:1685 Descripcion:1685 Ingredientes:1685 Pasos:1685 Urls:1685
#  Categoria: 1714 Titulo:1714 Descripcion:1714 Ingredientes:1714 Pasos:1714 Urls:1714
#  Categoria: 1778 Titulo:1778 Descripcion:1778 Ingredientes:1778 Pasos:1778 Urls:1778
#  Categoria: 1842 Titulo:1842 Descripcion:1842 Ingredientes:1842 Pasos:1842 Urls:1842
#  Categoria: 1850 Titulo:1850 Descripcion:1850 Ingredientes:1850 Pasos:1850 Urls:1850
#  Categoria: 1914 Titulo:1914 Descripcion:1914 Ingredientes:1914 Pasos:1914 Urls:1914
#  Categoria: 1978 Titulo:1978 Descripcion:1978 Ingredientes:1978 Pasos:1978 Urls:1978
#  Categoria: 2042 Titulo:2042 Descripcion:2042 Ingredientes:2042 Pasos:2042 Urls:2042
#  Categoria: 2106 Titulo:2106 Descripcion:2106 Ingredientes:2106 Pasos:2106 Urls:2106
#  Categoria: 2170 Titulo:2170 Descripcion:2170 Ingredientes:2170 Pasos:2170 Urls:2170
#  Categoria: 2234 Titulo:2234 Descripcion:2234 Ingredientes:2234 Pasos:2234 Urls:2234
#  Categoria: 2254 Titulo:2254 Descripcion:2254 Ingredientes:2254 Pasos:2254 Urls:2254
#  Categoria: 2318 Titulo:2318 Descripcion:2318 Ingredientes:2318 Pasos:2318 Urls:2318
#  Categoria: 2356 Titulo:2356 Descripcion:2356 Ingredientes:2356 Pasos:2356 Urls:2356
#  Categoria: 2397 Titulo:2397 Descripcion:2397 Ingredientes:2397 Pasos:2397 Urls:2397
#  Categoria: 2461 Titulo:2461 Descripcion:2461 Ingredientes:2461 Pasos:2461 Urls:2461
#  Categoria: 2525 Titulo:2525 Descripcion:2525 Ingredientes:2525 Pasos:2525 Urls:2525
#  Categoria: 2589 Titulo:2589 Descripcion:2589 Ingredientes:2589 Pasos:2589 Urls:2589
#  Categoria: 2653 Titulo:2653 Descripcion:2653 Ingredientes:2653 Pasos:2653 Urls:2653
#  Categoria: 2717 Titulo:2717 Descripcion:2717 Ingredientes:2717 Pasos:2717 Urls:2717
#  Categoria: 2781 Titulo:2781 Descripcion:2781 Ingredientes:2781 Pasos:2781 Urls:2781
#  Categoria: 2845 Titulo:2845 Descripcion:2845 Ingredientes:2845 Pasos:2845 Urls:2845
#  Categoria: 2909 Titulo:2909 Descripcion:2909 Ingredientes:2909 Pasos:2909 Urls:2909
#  Categoria: 2973 Titulo:2973 Descripcion:2973 Ingredientes:2973 Pasos:2973 Urls:2973
#  Categoria: 3037 Titulo:3037 Descripcion:3037 Ingredientes:3037 Pasos:3037 Urls:3037
#  Categoria: 3101 Titulo:3101 Descripcion:3101 Ingredientes:3101 Pasos:3101 Urls:3101
#  Categoria: 3136 Titulo:3136 Descripcion:3136 Ingredientes:3136 Pasos:3136 Urls:3136
#  Categoria: 3200 Titulo:3200 Descripcion:3200 Ingredientes:3200 Pasos:3200 Urls:3200
#  Categoria: 3264 Titulo:3264 Descripcion:3264 Ingredientes:3264 Pasos:3264 Urls:3264
#  Categoria: 3328 Titulo:3328 Descripcion:3328 Ingredientes:3328 Pasos:3328 Urls:3328
#  Categoria: 3392 Titulo:3392 Descripcion:3392 Ingredientes:3392 Pasos:3392 Urls:3392
#  Categoria: 3401 Titulo:3401 Descripcion:3401 Ingredientes:3401 Pasos:3401 Urls:3401
#  Categoria: 3423 Titulo:3423 Descripcion:3423 Ingredientes:3423 Pasos:3423 Urls:3423
#  Categoria: 3487 Titulo:3487 Descripcion:3487 Ingredientes:3487 Pasos:3487 Urls:3487
#  Categoria: 3551 Titulo:3551 Descripcion:3551 Ingredientes:3551 Pasos:3551 Urls:3551
#  Categoria: 3615 Titulo:3615 Descripcion:3615 Ingredientes:3615 Pasos:3615 Urls:3615
#  Categoria: 3669 Titulo:3669 Descripcion:3669 Ingredientes:3669 Pasos:3669 Urls:3669
#  Categoria: 3733 Titulo:3733 Descripcion:3733 Ingredientes:3733 Pasos:3733 Urls:3733
#  Categoria: 3797 Titulo:3797 Descripcion:3797 Ingredientes:3797 Pasos:3797 Urls:3797
#  Categoria: 3861 Titulo:3861 Descripcion:3861 Ingredientes:3861 Pasos:3861 Urls:3861
#  Categoria: 3914 Titulo:3914 Descripcion:3914 Ingredientes:3914 Pasos:3914 Urls:3914

# %% [markdown]
# Guardamos la data en un archivo csv

# %%
df_registro = pd.DataFrame({
    "Categoria": lista_categorias,
    "Nombre":lista_titulos,
    "Descripcion": lista_descripcion,
    "Ingredientes": lista_ingredientes,
    "Pasos":lista_pasos,
    "Links": lista_urls
})
df_registro = df_registro.drop_duplicates(subset="Links")
df_registro.to_csv("AllRecipes-Corpus-v2.csv", encoding='utf-8', index=False)

# %% [markdown]
# # Sistema de Recuperacion

# %%
import pandas as pd
archivo_csv = './AllRecipes-Corpus-v2.csv'
df = pd.read_csv(archivo_csv)

# %%
# Crear la columna 'ID' asignando un ID único a cada categoría
df['ID'] = df['Categoria'].astype('category').cat.codes + 1

# Crear un subíndice incremental para cada fila dentro de una categoría
df['SubID'] = df.groupby('ID').cumcount() + 1

# Combinar 'ID' y 'SubID' para crear el índice compuesto
df['ID_Completo'] = df['ID'].astype(str) + '.' + df['SubID'].astype(str)

# Reorganizar las columnas para que 'ID_Completo' sea la primera
df = df[['ID_Completo'] + [col for col in df.columns if col != 'ID_Completo']]

# Guardar el archivo con los IDs generados
df.to_csv('archivo_con_ids_compuestos.csv', index=False)

# %%
df_final=df[['ID','ID_Completo','Categoria','Nombre','Descripcion','Ingredientes','Pasos','Links']]
df_final
# Out:
#       ID ID_Completo    Categoria                                     Nombre  \
# 0      1         1.1  Almond Meal                Quick Almond Flour Pancakes
# 1      1         1.2  Almond Meal              90-Second Keto Bread in a Mug
# 2      1         1.3  Almond Meal                Macarons (French Macaroons)
# 3      1         1.4  Almond Meal                 Chaffles with Almond Flour
# 4      1         1.5  Almond Meal             Almond Flour-Blueberry Muffins
# ...   ..         ...          ...                                        ...
# 3523  69       69.44    Wild Rice        Chicken and Mushroom Wild Rice Soup
# 3524  69       69.45    Wild Rice       Ekaterina's Wild Rice and Kale Salad
# 3525  69       69.46    Wild Rice                      Calico Wild Rice Soup
# 3526  69       69.47    Wild Rice  Instant Pot Chicken and Wild Rice Chowder
# 3527  69       69.48    Wild Rice                          Wild Rice Soup II
#
#                                             Descripcion  \
# 0     These almond flour pancakes are a wonderful su...
# 1     Try keto bread microwaved quickly and easily w...
# 2     Macarons are made with finely ground almonds, ...
# 3     This chaffle recipe uses almond flour to creat...
# 4     These healthy, tender, almond flour-blueberry ...
# ...                                                 ...
# 3523  A slight variation on a recipe I received from...
# 3524  Healthy and filling, this salad is perfect for...
# 3525  This is a very hearty and flavorful soup, I do...
# 3526  When I was a little girl, my mamaw made a chic...
# 3527       Hearty and full of flavor, a meal in itself.
#
#                                            Ingredientes  \
# 0     1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1     1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2     3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3     1largeegg 1tablespoonblanched almond flour ¼te...
# 4     2cupsfinely ground almond flour ½teaspoonbakin...
# ...                                                 ...
# 3523  ½cupbutter 1finely chopped onion ½cupchopped c...
# 3524  3 ¼cupswater, divided ½cupwild rice ½cupbarley...
# 3525  2cupswild rice 6cupswater 4cupschicken broth 1...
# 3526  3tablespoonsbutter ½cupsliced mushrooms 1shall...
# 3527  ½cupdry lentils 3cupswater 1(6 ounce) packageu...
#
#                                                   Pasos  \
# 0     Gather all ingredients. Dotdash Meredith Food ...
# 1     Microwave butter in a microwave-safe mug until...
# 2     Line a baking sheet with a silicone baking mat...
# 3     Whisk egg, almond flour, and baking powder tog...
# 4     Preheat the oven to 350 degrees F (175 degrees...
# ...                                                 ...
# 3523  Gather the ingredients. Melt butter in a large...
# 3524  Bring 2 cups water and wild rice to a boil in ...
# 3525  In a medium sauce pan cook rice in 6 cups wate...
# 3526  Turn on a multi-functional pressure cooker (su...
# 3527  Rinse and sort lentils, discarding any debris ...
#
#                                                   Links
# 0     https://www.allrecipes.com/recipe/234702/quick...
# 1     https://www.allrecipes.com/recipe/263032/90-se...
# 2     https://www.allrecipes.com/recipe/223234/macar...
# 3     https://www.allrecipes.com/recipe/278328/chaff...
# 4     https://www.allrecipes.com/recipe/283581/almon...
# ...                                                 ...
# 3523  https://www.allrecipes.com/recipe/18448/chicke...
# 3524  https://www.allrecipes.com/recipe/255848/ekate...
# 3525  https://www.allrecipes.com/recipe/13383/calico...
# 3526  https://www.allrecipes.com/recipe/277361/insta...
# 3527  https://www.allrecipes.com/recipe/13273/wild-r...
#
# [3528 rows x 8 columns]

# %%
df_final.isna().sum()
# Out:
# ID              0
# ID_Completo     0
# Categoria       0
# Nombre          0
# Descripcion     0
# Ingredientes    0
# Pasos           0
# Links           0
# dtype: int64

# %%
df_final.loc[:, 'textoLimpio'] = df_final['Descripcion'].str.lower().str.replace('.', '', regex=False).str.replace(',', '', regex=False)
# Out:
# <ipython-input-75-abc69e1f7095>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.loc[:, 'textoLimpio'] = df_final['Descripcion'].str.lower().str.replace('.', '', regex=False).str.replace(',', '', regex=False)

# %%
df_final.head()
# Out:
#    ID ID_Completo    Categoria                          Nombre  \
# 0   1         1.1  Almond Meal     Quick Almond Flour Pancakes
# 1   1         1.2  Almond Meal   90-Second Keto Bread in a Mug
# 2   1         1.3  Almond Meal     Macarons (French Macaroons)
# 3   1         1.4  Almond Meal      Chaffles with Almond Flour
# 4   1         1.5  Almond Meal  Almond Flour-Blueberry Muffins
#
#                                          Descripcion  \
# 0  These almond flour pancakes are a wonderful su...
# 1  Try keto bread microwaved quickly and easily w...
# 2  Macarons are made with finely ground almonds, ...
# 3  This chaffle recipe uses almond flour to creat...
# 4  These healthy, tender, almond flour-blueberry ...
#
#                                         Ingredientes  \
# 0  1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1  1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2  3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3  1largeegg 1tablespoonblanched almond flour ¼te...
# 4  2cupsfinely ground almond flour ½teaspoonbakin...
#
#                                                Pasos  \
# 0  Gather all ingredients. Dotdash Meredith Food ...
# 1  Microwave butter in a microwave-safe mug until...
# 2  Line a baking sheet with a silicone baking mat...
# 3  Whisk egg, almond flour, and baking powder tog...
# 4  Preheat the oven to 350 degrees F (175 degrees...
#
#                                                Links  \
# 0  https://www.allrecipes.com/recipe/234702/quick...
# 1  https://www.allrecipes.com/recipe/263032/90-se...
# 2  https://www.allrecipes.com/recipe/223234/macar...
# 3  https://www.allrecipes.com/recipe/278328/chaff...
# 4  https://www.allrecipes.com/recipe/283581/almon...
#
#                                          textoLimpio
# 0  these almond flour pancakes are a wonderful su...
# 1  try keto bread microwaved quickly and easily w...
# 2  macarons are made with finely ground almonds c...
# 3  this chaffle recipe uses almond flour to creat...
# 4  these healthy tender almond flour-blueberry mu...

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

df_final.loc[:, 'tokens'] = df_final['textoLimpio'].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df_final.head()
# Out:
#    ID ID_Completo    Categoria                          Nombre  \
# 0   1         1.1  Almond Meal     Quick Almond Flour Pancakes
# 1   1         1.2  Almond Meal   90-Second Keto Bread in a Mug
# 2   1         1.3  Almond Meal     Macarons (French Macaroons)
# 3   1         1.4  Almond Meal      Chaffles with Almond Flour
# 4   1         1.5  Almond Meal  Almond Flour-Blueberry Muffins
#
#                                          Descripcion  \
# 0  These almond flour pancakes are a wonderful su...
# 1  Try keto bread microwaved quickly and easily w...
# 2  Macarons are made with finely ground almonds, ...
# 3  This chaffle recipe uses almond flour to creat...
# 4  These healthy, tender, almond flour-blueberry ...
#
#                                         Ingredientes  \
# 0  1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1  1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2  3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3  1largeegg 1tablespoonblanched almond flour ¼te...
# 4  2cupsfinely ground almond flour ½teaspoonbakin...
#
#                                                Pasos  \
# 0  Gather all ingredients. Dotdash Meredith Food ...
# 1  Microwave butter in a microwave-safe mug until...
# 2  Line a baking sheet with a silicone baking mat...
# 3  Whisk egg, almond flour, and baking powder tog...
# 4  Preheat the oven to 350 degrees F (175 degrees...
#
#                                                Links  \
# 0  https://www.allrecipes.com/recipe/234702/quick...
# 1  https://www.allrecipes.com/recipe/263032/90-se...
# 2  https://www.allrecipes.com/recipe/223234/macar...
# 3  https://www.allrecipes.com/recipe/278328/chaff...
# 4  https://www.allrecipes.com/recipe/283581/almon...
#
#                                          textoLimpio  \
# 0  these almond flour pancakes are a wonderful su...
# 1  try keto bread microwaved quickly and easily w...
# 2  macarons are made with finely ground almonds c...
# 3  this chaffle recipe uses almond flour to creat...
# 4  these healthy tender almond flour-blueberry mu...
#
#                                               tokens
# 0  [these, almond, flour, pancakes, are, a, wonde...
# 1  [try, keto, bread, microwaved, quickly, and, e...
# 2  [macarons, are, made, with, finely, ground, al...
# 3  [this, chaffle, recipe, uses, almond, flour, t...
# 4  [these, healthy, tender, almond, flour-blueber...

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
df_final.loc[:, 'tokens'] = df_final['tokens'].apply(lambda tokens: [token for token in tokens if token not in stop_words])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_final.head()
# Out:
#    ID ID_Completo    Categoria                          Nombre  \
# 0   1         1.1  Almond Meal     Quick Almond Flour Pancakes
# 1   1         1.2  Almond Meal   90-Second Keto Bread in a Mug
# 2   1         1.3  Almond Meal     Macarons (French Macaroons)
# 3   1         1.4  Almond Meal      Chaffles with Almond Flour
# 4   1         1.5  Almond Meal  Almond Flour-Blueberry Muffins
#
#                                          Descripcion  \
# 0  These almond flour pancakes are a wonderful su...
# 1  Try keto bread microwaved quickly and easily w...
# 2  Macarons are made with finely ground almonds, ...
# 3  This chaffle recipe uses almond flour to creat...
# 4  These healthy, tender, almond flour-blueberry ...
#
#                                         Ingredientes  \
# 0  1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1  1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2  3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3  1largeegg 1tablespoonblanched almond flour ¼te...
# 4  2cupsfinely ground almond flour ½teaspoonbakin...
#
#                                                Pasos  \
# 0  Gather all ingredients. Dotdash Meredith Food ...
# 1  Microwave butter in a microwave-safe mug until...
# 2  Line a baking sheet with a silicone baking mat...
# 3  Whisk egg, almond flour, and baking powder tog...
# 4  Preheat the oven to 350 degrees F (175 degrees...
#
#                                                Links  \
# 0  https://www.allrecipes.com/recipe/234702/quick...
# 1  https://www.allrecipes.com/recipe/263032/90-se...
# 2  https://www.allrecipes.com/recipe/223234/macar...
# 3  https://www.allrecipes.com/recipe/278328/chaff...
# 4  https://www.allrecipes.com/recipe/283581/almon...
#
#                                          textoLimpio  \
# 0  these almond flour pancakes are a wonderful su...
# 1  try keto bread microwaved quickly and easily w...
# 2  macarons are made with finely ground almonds c...
# 3  this chaffle recipe uses almond flour to creat...
# 4  these healthy tender almond flour-blueberry mu...
#
#                                               tokens
# 0  [almond, flour, pancakes, wonderful, substitut...
# 1  [try, keto, bread, microwaved, quickly, easily...
# 2  [macarons, made, finely, ground, almonds, conf...
# 3  [chaffle, recipe, uses, almond, flour, create,...
# 4  [healthy, tender, almond, flour-blueberry, muf...

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# %%
 #Entrenamiento de Word2Vec
# Crear una lista de listas de palabras (tokens) para entrenar Word2Vec
sentences = df_final['tokens'].tolist()

# Entrenar el modelo Word2Vec
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# 3. Obtener embeddings para cada frase
# Función para promediar los vectores de palabras en cada oración
def obtener_embedding(tokens, model):
    vectors = [model.wv[word] for word in tokens if word in model.wv]
    if vectors:
        return sum(vectors) / len(vectors)  # Promedio de vectores
    else:
        return [0] * model.vector_size  # Si no hay palabras en el vocabulario, retornar ceros

# %%
 #Entrenamiento de Word2Vec
# Crear una lista de listas de palabras (tokens) para entrenar Word2Vec
sentences = df_final['tokens'].tolist()

# Entrenar el modelo Word2Vec
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# 3. Obtener embeddings para cada frase
# Función para promediar los vectores de palabras en cada oración
def obtener_embedding(tokens, model):
    vectors = [model.wv[word] for word in tokens if word in model.wv]
    if vectors:
        return sum(vectors) / len(vectors)  # Promedio de vectores
    else:
        return [0] * model.vector_size  # Si no hay palabras en el vocabulario, retornar ceros

# %%
# Aplicar la función para obtener los embeddings
df_final['embedding'] = df_final['tokens'].apply(lambda x: obtener_embedding(x, model))

df_final
# Out:
#       ID ID_Completo    Categoria                                     Nombre  \
# 0      1         1.1  Almond Meal                Quick Almond Flour Pancakes
# 1      1         1.2  Almond Meal              90-Second Keto Bread in a Mug
# 2      1         1.3  Almond Meal                Macarons (French Macaroons)
# 3      1         1.4  Almond Meal                 Chaffles with Almond Flour
# 4      1         1.5  Almond Meal             Almond Flour-Blueberry Muffins
# ...   ..         ...          ...                                        ...
# 3523  69       69.44    Wild Rice        Chicken and Mushroom Wild Rice Soup
# 3524  69       69.45    Wild Rice       Ekaterina's Wild Rice and Kale Salad
# 3525  69       69.46    Wild Rice                      Calico Wild Rice Soup
# 3526  69       69.47    Wild Rice  Instant Pot Chicken and Wild Rice Chowder
# 3527  69       69.48    Wild Rice                          Wild Rice Soup II
#
#                                             Descripcion  \
# 0     These almond flour pancakes are a wonderful su...
# 1     Try keto bread microwaved quickly and easily w...
# 2     Macarons are made with finely ground almonds, ...
# 3     This chaffle recipe uses almond flour to creat...
# 4     These healthy, tender, almond flour-blueberry ...
# ...                                                 ...
# 3523  A slight variation on a recipe I received from...
# 3524  Healthy and filling, this salad is perfect for...
# 3525  This is a very hearty and flavorful soup, I do...
# 3526  When I was a little girl, my mamaw made a chic...
# 3527       Hearty and full of flavor, a meal in itself.
#
#                                            Ingredientes  \
# 0     1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1     1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2     3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3     1largeegg 1tablespoonblanched almond flour ¼te...
# 4     2cupsfinely ground almond flour ½teaspoonbakin...
# ...                                                 ...
# 3523  ½cupbutter 1finely chopped onion ½cupchopped c...
# 3524  3 ¼cupswater, divided ½cupwild rice ½cupbarley...
# 3525  2cupswild rice 6cupswater 4cupschicken broth 1...
# 3526  3tablespoonsbutter ½cupsliced mushrooms 1shall...
# 3527  ½cupdry lentils 3cupswater 1(6 ounce) packageu...
#
#                                                   Pasos  \
# 0     Gather all ingredients. Dotdash Meredith Food ...
# 1     Microwave butter in a microwave-safe mug until...
# 2     Line a baking sheet with a silicone baking mat...
# 3     Whisk egg, almond flour, and baking powder tog...
# 4     Preheat the oven to 350 degrees F (175 degrees...
# ...                                                 ...
# 3523  Gather the ingredients. Melt butter in a large...
# 3524  Bring 2 cups water and wild rice to a boil in ...
# 3525  In a medium sauce pan cook rice in 6 cups wate...
# 3526  Turn on a multi-functional pressure cooker (su...
# 3527  Rinse and sort lentils, discarding any debris ...
#
#                                                   Links  \
# 0     https://www.allrecipes.com/recipe/234702/quick...
# 1     https://www.allrecipes.com/recipe/263032/90-se...
# 2     https://www.allrecipes.com/recipe/223234/macar...
# 3     https://www.allrecipes.com/recipe/278328/chaff...
# 4     https://www.allrecipes.com/recipe/283581/almon...
# ...                                                 ...
# 3523  https://www.allrecipes.com/recipe/18448/chicke...
# 3524  https://www.allrecipes.com/recipe/255848/ekate...
# 3525  https://www.allrecipes.com/recipe/13383/calico...
# 3526  https://www.allrecipes.com/recipe/277361/insta...
# 3527  https://www.allrecipes.com/recipe/13273/wild-r...
#
#                                             textoLimpio  \
# 0     these almond flour pancakes are a wonderful su...
# 1     try keto bread microwaved quickly and easily w...
# 2     macarons are made with finely ground almonds c...
# 3     this chaffle recipe uses almond flour to creat...
# 4     these healthy tender almond flour-blueberry mu...
# ...                                                 ...
# 3523  a slight variation on a recipe i received from...
# 3524  healthy and filling this salad is perfect for ...
# 3525  this is a very hearty and flavorful soup i do ...
# 3526  when i was a little girl my mamaw made a chick...
# 3527         hearty and full of flavor a meal in itself
#
#                                                  tokens  \
# 0     [almond, flour, pancakes, wonderful, substitut...
# 1     [try, keto, bread, microwaved, quickly, easily...
# 2     [macarons, made, finely, ground, almonds, conf...
# 3     [chaffle, recipe, uses, almond, flour, create,...
# 4     [healthy, tender, almond, flour-blueberry, muf...
# ...                                                 ...
# 3523  [slight, variation, recipe, received, fellow, ...
# 3524  [healthy, filling, salad, perfect, lunch, ligh...
# 3525    [hearty, flavorful, soup, believe, enjoy, !, !]
# 3526  [little, girl, mamaw, made, chicken, casserole...
# 3527                       [hearty, full, flavor, meal]
#
#                                               embedding
# 0     [-0.17397314, 0.35485378, 0.0730868, 0.0579810...
# 1     [-0.19779213, 0.39884582, 0.079875164, 0.06729...
# 2     [-0.16381578, 0.33807915, 0.068985015, 0.05124...
# 3     [-0.16592766, 0.33546615, 0.06739347, 0.053851...
# 4     [-0.20216085, 0.40848288, 0.08354452, 0.068534...
# ...                                                 ...
# 3523  [-0.18565513, 0.3739121, 0.07516736, 0.0628829...
# 3524  [-0.23697631, 0.48668578, 0.095420934, 0.07665...
# 3525  [-0.2670103, 0.53904444, 0.10641797, 0.0919911...
# 3526  [-0.18128169, 0.36434838, 0.071414016, 0.05183...
# 3527  [-0.27634302, 0.5509566, 0.10518184, 0.0895724...
#
# [3528 rows x 11 columns]

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Asegúrate de que la columna de embeddings es una lista de numpy arrays
embeddings = np.array(df_final['embedding'].tolist())

# Número de clusters (esto puedes ajustarlo según tus necesidades)
n_clusters = 5

# Aplicar K-Means
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df_final['cluster'] = kmeans.fit_predict(embeddings)

# Mostrar el resultado
df_final.head()
# Out:
#    ID ID_Completo    Categoria                          Nombre  \
# 0   1         1.1  Almond Meal     Quick Almond Flour Pancakes
# 1   1         1.2  Almond Meal   90-Second Keto Bread in a Mug
# 2   1         1.3  Almond Meal     Macarons (French Macaroons)
# 3   1         1.4  Almond Meal      Chaffles with Almond Flour
# 4   1         1.5  Almond Meal  Almond Flour-Blueberry Muffins
#
#                                          Descripcion  \
# 0  These almond flour pancakes are a wonderful su...
# 1  Try keto bread microwaved quickly and easily w...
# 2  Macarons are made with finely ground almonds, ...
# 3  This chaffle recipe uses almond flour to creat...
# 4  These healthy, tender, almond flour-blueberry ...
#
#                                         Ingredientes  \
# 0  1cupalmond flour ¼cupwater 2eggs 1tablespoonma...
# 1  1tablespoonbutter ⅓cupblanched almond flour 1e...
# 2  3egg whites ¼cupwhite sugar 1 ⅔cupsconfectione...
# 3  1largeegg 1tablespoonblanched almond flour ¼te...
# 4  2cupsfinely ground almond flour ½teaspoonbakin...
#
#                                                Pasos  \
# 0  Gather all ingredients. Dotdash Meredith Food ...
# 1  Microwave butter in a microwave-safe mug until...
# 2  Line a baking sheet with a silicone baking mat...
# 3  Whisk egg, almond flour, and baking powder tog...
# 4  Preheat the oven to 350 degrees F (175 degrees...
#
#                                                Links  \
# 0  https://www.allrecipes.com/recipe/234702/quick...
# 1  https://www.allrecipes.com/recipe/263032/90-se...
# 2  https://www.allrecipes.com/recipe/223234/macar...
# 3  https://www.allrecipes.com/recipe/278328/chaff...
# 4  https://www.allrecipes.com/recipe/283581/almon...
#
#                                          textoLimpio  \
# 0  these almond flour pancakes are a wonderful su...
# 1  try keto bread microwaved quickly and easily w...
# 2  macarons are made with finely ground almonds c...
# 3  this chaffle recipe uses almond flour to creat...
# 4  these healthy tender almond flour-blueberry mu...
#
#                                               tokens  \
# 0  [almond, flour, pancakes, wonderful, substitut...
# 1  [try, keto, bread, microwaved, quickly, easily...
# 2  [macarons, made, finely, ground, almonds, conf...
# 3  [chaffle, recipe, uses, almond, flour, create,...
# 4  [healthy, tender, almond, flour-blueberry, muf...
#
#                                            embedding  cluster
# 0  [-0.17397314, 0.35485378, 0.0730868, 0.0579810...        2
# 1  [-0.19779213, 0.39884582, 0.079875164, 0.06729...        2
# 2  [-0.16381578, 0.33807915, 0.068985015, 0.05124...        2
# 3  [-0.16592766, 0.33546615, 0.06739347, 0.053851...        2
# 4  [-0.20216085, 0.40848288, 0.08354452, 0.068534...        4

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Obtener los centroides de cada cluster
centroides = kmeans.cluster_centers_

# Función para encontrar la similitud coseno entre un vector y el centroide de un cluster
def obtener_similitud_con_centroide(embedding, centroide):
    return cosine_similarity([embedding], [centroide])[0][0]

# Crear un diccionario para almacenar las oraciones más representativas de cada cluster
oraciones_topico = {}

# Iterar sobre cada cluster y encontrar las oraciones más cercanas al centroide
for cluster_id in range(n_clusters):
    # Obtener las oraciones en este cluster
    oraciones_cluster = df_final[df_final['cluster'] == cluster_id]

    # Obtener los embeddings de estas oraciones
    embeddings_cluster = np.array(oraciones_cluster['embedding'].tolist())

    # Calcular la similitud coseno entre cada embedding y el centroide del cluster
    similitudes = [obtener_similitud_con_centroide(embedding, centroides[cluster_id]) for embedding in embeddings_cluster]

    # Encontrar el índice de la oración más cercana al centroide
    indice_max_similitud = np.argmax(similitudes)

    # Obtener la oración más representativa y asociarla con el cluster
    oracion_representativa = oraciones_cluster.iloc[indice_max_similitud]['Descripcion']

    # Guardar la oración más representativa en el diccionario
    oraciones_topico[cluster_id] = oracion_representativa

# Mostrar las oraciones más representativas de cada cluster (tópico)
for cluster_id, oracion in oraciones_topico.items():
    print(f"Cluster {cluster_id}: {oracion}")
# Out:
# Cluster 0: This easy venison recipe is the simple and tasty way I make venison. Like anything else, it is better with fresh ingredients rather than canned, but this is what I had on hand. Wonderful served over brown or wild rice.
# Cluster 1: The reason I'm calling this salsa verde and not pesto is because whenever you say pesto, people instantly think of the traditional version with the pine nuts and basil. I'm using the term salsa verde the way it's used around northern California. It's a very generic term for any fresh green sauce, usually starring some type of herb, but also can be made with spinach, arugula, etc.
# Cluster 2: If you're like most people, you've probably made the same turkey every Thanksgiving, year after year. Why not jazz up the flavor this time with a little pomegranate molasses? This Middle Eastern syrup is sweet but also deeply flavored with a little sourness. Think of it as a puckered-up version of balsamic vinegar. They're both irresistible. You can make your own pomegranate molasses (our recipe comes courtesy of Allrecipes reader, Flying Chef) or buy a bottle. Mix it with some sharp horseradish and mustard, as well as some chopped fresh sage for a familiar Thanksgiving flavor and you have a juicy, delicious turkey. Everyone will want seconds of this one.
# Cluster 3: No Disponible
# Cluster 4: This simple yet effective Boston butt recipe gives the pulled pork a mildly spicy and tangy flavor. The combination of smoke and moisture from the drip pan works very well for cooking the meat evenly and leaves plenty of juices within the meat itself. I've tried several different methods with Boston butt and this one is my favorite, as well as a favorite among my friends. Give it a try and see if you like it, and please don't be shy and leave some feedback! I usually serve with barbeque sauce and baked beans (throwing the fat chunks from the pulled pork into the beans to add a little extra flavor). Check out my Sweet and Spicy Cornbread Muffins recipe for a great side. Enjoy!

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity


def obtener_embedding_busqueda(clave, modelo):
    """Genera un embedding para las palabras clave usando el modelo proporcionado."""
    tokens = clave.split()
    vectores = [modelo.wv[word] for word in tokens if word in modelo.wv]
    if len(vectores) > 0:
        return np.mean(vectores, axis=0)
    else:
        return np.zeros(modelo.vector_size)


def buscar_por_topico(clave, modelo, df, top_n=5):
    """
    Busca recetas en el DataFrame basado en la similitud coseno entre embeddings.

    Args:
        clave: Palabras clave de búsqueda.
        modelo: Modelo de word embeddings (e.g., Word2Vec).
        df: DataFrame con los datos y embeddings.
        top_n: Número de resultados a devolver.

    Returns:
        DataFrame con las recetas más relevantes según la búsqueda.
    """
    # Obtener el embedding de la búsqueda
    embedding_busqueda = obtener_embedding_busqueda(clave, modelo)

    # Calcular similitud coseno con los embeddings de las recetas
    embeddings_oraciones = np.array(df['embedding'].tolist())
    similitudes = cosine_similarity([embedding_busqueda], embeddings_oraciones)[0]

    # Agregar la similitud al DataFrame
    df['similitud'] = similitudes

    # Ordenar por similitud y seleccionar los top_n resultados
    resultados = df.sort_values(by='similitud', ascending=False).head(top_n)

    return resultados


def obtener_titulo_por_id(ids, df):
    """
    Filtra las filas del DataFrame que coinciden con los IDs proporcionados.

    Args:
        ids: Lista de IDs a buscar.
        df: DataFrame con los datos de las recetas.

    Returns:
        DataFrame con los campos relevantes.
    """
    return df[df['ID'].isin(ids)][['ID', 'ID_Completo', 'Nombre', 'Links']]

# Realizar la búsqueda
clave_busqueda = "macaroons"  # Palabras clave de búsqueda
resultados_busqueda = buscar_por_topico(clave_busqueda, model, df_final)

# Obtener los IDs de las recetas relevantes
ids_resultados = resultados_busqueda['ID'].tolist()

# Filtrar y obtener los detalles de las recetas
resultados_finales = obtener_titulo_por_id(ids_resultados, df_final)

# Mostrar resultados finales
print(resultados_finales)
# Out:
#       ID ID_Completo                                  Nombre  \
# 0      1         1.1             Quick Almond Flour Pancakes
# 1      1         1.2           90-Second Keto Bread in a Mug
# 2      1         1.3             Macarons (French Macaroons)
# 3      1         1.4              Chaffles with Almond Flour
# 4      1         1.5          Almond Flour-Blueberry Muffins
# ...   ..         ...                                     ...
# 2578  49       49.56    Schnitzbrot (German Christmas Bread)
# 2579  49       49.57  Rogaliki (Polish Jam-Filled Crescents)
# 2580  49       49.58       Zwetschekuchen (German Plum Tart)
# 2581  49       49.59                             Plum Buckle
# 2582  49       49.60                     Zucchini Plum Bread
#
#                                                   Links
# 0     https://www.allrecipes.com/recipe/234702/quick...
# 1     https://www.allrecipes.com/recipe/263032/90-se...
# 2     https://www.allrecipes.com/recipe/223234/macar...
# 3     https://www.allrecipes.com/recipe/278328/chaff...
# 4     https://www.allrecipes.com/recipe/283581/almon...
# ...                                                 ...
# 2578  https://www.allrecipes.com/recipe/155762/schni...
# 2579  https://www.allrecipes.com/recipe/262728/rogal...
# 2580  https://www.allrecipes.com/recipe/215133/zwets...
# 2581  https://www.allrecipes.com/recipe/215132/plum-...
# 2582  https://www.allrecipes.com/recipe/234327/zucch...
#
# [309 rows x 4 columns]
