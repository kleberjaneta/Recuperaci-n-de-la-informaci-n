# %% [markdown]
# # Ejercicio 03: Cálculo de Relevancia y Ranking de Documentos
#
# El objetivo de este ejercicio es calcular analíticamente la relevancia de cada documento en un corpus y luego ordenar (rankear) los documentos basándonos en esa puntuación de relevancia para tres consultas específicas. Seguirás los siguientes pasos:

# %% [markdown]
# Descripción del Ejercicio
#
# 1. Procesamiento del Corpus:
#     * Leer y parsear el archivo XML proporcionado que contiene el corpus de documentos con sus metadatos (keywords, autor y fecha).
#
# 2. Procesamiento de las Consultas:
#     * Definir las consultas proporcionadas.
#     * Extraer las palabras clave de cada consulta.
#
# 3. Cálculo de Relevancia:
#     * Utilizar métricas de similitud (Similitud Coseno y Jaccard) entre la representación vectorial de los documentos y las de las consultas.
#     * Calcular la puntuación de relevancia para cada documento del corpus respecto a cada consulta.
#
# 4. Ranking de Documentos:
#     * Ordenar los documentos en función de su puntuación de relevancia de mayor a menor.
#     * Mostrar el ranking de documentos para cada consulta.

# %%
# Importar las librerías necesarias
import xml.etree.ElementTree as ET

# Definir las consultas
queries = {
    1: "Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios",
    2: "Actividades extracurriculares y bienestar emocional en el campus universitario",
    3: "Estrategias universitarias para reducir el estrés en estudiantes"
}

# Función para procesar el texto y extraer palabras clave
def process_text(text):
    # Convertir a minúsculas
    text = text.lower()
    # Reemplazar caracteres no alfanuméricos por espacios
    import re
    text = re.sub(r'[^a-záéíóúñü]+', ' ', text)
    # Tokenizar y eliminar palabras vacías si es necesario
    tokens = text.strip().split()
    return set(tokens)

# Paso 1: Leer y parsear el archivo XML
def parse_corpus(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    corpus = {}
    for doc in root.findall('document'):
        doc_id = int(doc.get('id'))
        title = doc.find('title').text
        keywords = doc.find('keywords').text
        author = doc.find('author').text
        date = doc.find('date').text
        # Procesar las palabras clave
        keyword_set = process_text(keywords)
        corpus[doc_id] = {
            'title': title,
            'keywords': keyword_set,
            'author': author,
            'date': date
        }
    return corpus

# %%
corpus = parse_corpus('../content/sample_data/03ranking_corpus.xml')
corpus
# Out:
# {1: {'title': 'El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.',
#   'keywords': {'crónica',
#    'médica',
#    'salud',
#    'tecnología',
#    'telemedicina',
#    'tratamiento'},
#   'author': 'Dr. Juan Pérez',
#   'date': '2023-01-15'},
#  2: {'title': 'Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.',
#   'keywords': {'académico',
#    'estudiantes',
#    'mental',
#    'nutrición',
#    'rendimiento',
#    'salud'},
#   'author': 'Dra. María López',
#   'date': '2023-02-10'},
#  3: {'title': 'Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.',
#   'keywords': {'amistad',
#    'bienestar',
#    'campus',
#    'estudiantil',
#    'relaciones',
#    'sociales'},
#   'author': 'Miguel Rodríguez',
#   'date': '2023-03-05'},
#  4: {'title': 'El rol de las bibliotecas universitarias en el fomento de la investigación académica.',
#   'keywords': {'academia',
#    'bibliotecas',
#    'investigación',
#    'recursos',
#    'universitarias'},
#   'author': 'Lucía Martínez',
#   'date': '2023-04-20'},
#  5: {'title': 'Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.',
#   'keywords': {'campus',
#    'concentración',
#    'espacios',
#    'estrés',
#    'universitario',
#    'verdes'},
#   'author': 'Carlos Fernández',
#   'date': '2023-05-15'},
#  6: {'title': 'La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.',
#   'keywords': {'bienestar',
#    'cultura',
#    'estudiantes',
#    'hábitos',
#    'saludables',
#    'universitaria'},
#   'author': 'Ana Sánchez',
#   'date': '2023-06-10'},
#  7: {'title': 'La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.',
#   'keywords': {'académico',
#    'mental',
#    'rendimiento',
#    'salud',
#    'sueño',
#    'universitarios'},
#   'author': 'Javier Torres',
#   'date': '2023-07-25'},
#  8: {'title': 'La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.',
#   'keywords': {'apoyo',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'familiar',
#    'social'},
#   'author': 'Laura Gómez',
#   'date': '2023-08-30'},
#  9: {'title': 'El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.',
#   'keywords': {'adultos',
#    'cognitivo',
#    'de',
#    'desarrollo',
#    'hábitos',
#    'jóvenes',
#    'lectura'},
#   'author': 'Fernando Ruiz',
#   'date': '2023-09-18'},
#  10: {'title': 'Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.',
#   'keywords': {'avances',
#    'jóvenes',
#    'medicina',
#    'médica',
#    'preventiva',
#    'tecnología',
#    'tecnológicos'},
#   'author': 'Elena Navarro',
#   'date': '2023-10-05'},
#  11: {'title': 'Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'ejercicio',
#    'estrés',
#    'estudiantes',
#    'salud',
#    'universitarios'},
#   'author': 'Diego Castro',
#   'date': '2023-11-12'},
#  12: {'title': 'El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.',
#   'keywords': {'ansiedad',
#    'estudiantes',
#    'meditación',
#    'mindfulness',
#    'universitarios'},
#   'author': 'Sofía Vega',
#   'date': '2023-12-01'},
#  13: {'title': 'Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.',
#   'keywords': {'apoyo',
#    'de',
#    'estudiantes',
#    'estudio',
#    'grupos',
#    'mental',
#    'psicológico',
#    'salud',
#    'universitarios'},
#   'author': 'Marcos Ortiz',
#   'date': '2024-01-10'},
#  14: {'title': 'Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.',
#   'keywords': {'académico',
#    'desempeño',
#    'estudiantes',
#    'mental',
#    'salud',
#    'servicios',
#    'universitarios'},
#   'author': 'Paula Morales',
#   'date': '2024-02-15'},
#  15: {'title': 'Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.',
#   'keywords': {'actividades',
#    'bienestar',
#    'emocional',
#    'estudiantes',
#    'extracurriculares',
#    'social'},
#   'author': 'José Herrera',
#   'date': '2024-03-05'},
#  16: {'title': 'El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.',
#   'keywords': {'competencias',
#    'de',
#    'desarrollo',
#    'educación',
#    'innovación',
#    'laboratorios',
#    'tecnológicas'},
#   'author': 'Andrea Díaz',
#   'date': '2024-04-20'},
#  17: {'title': 'Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.',
#   'keywords': {'campus',
#    'colaboración',
#    'de',
#    'diseño',
#    'interacción',
#    'tendencias'},
#   'author': 'Sergio Muñoz',
#   'date': '2024-05-15'},
#  18: {'title': 'Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.',
#   'keywords': {'académico',
#    'bienestar',
#    'comparación',
#    'estudiantes',
#    'que',
#    'rendimiento',
#    'trabajan'},
#   'author': 'Isabel Flores',
#   'date': '2024-06-10'},
#  19: {'title': 'Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.',
#   'keywords': {'académico',
#    'agotamiento',
#    'de',
#    'estudiantes',
#    'factores',
#    'prevención',
#    'riesgo',
#    'universitarios'},
#   'author': 'Ricardo Ramos',
#   'date': '2024-07-25'},
#  20: {'title': 'El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.',
#   'keywords': {'calidad',
#    'del',
#    'estudiantes',
#    'redes',
#    'sociales',
#    'sueño',
#    'tecnología'},
#   'author': 'Valeria Castillo',
#   'date': '2024-08-30'},
#  21: {'title': 'Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.',
#   'keywords': {'ambiental',
#    'edificios',
#    'impacto',
#    'sostenibilidad',
#    'tecnologías',
#    'universitarios',
#    'verdes'},
#   'author': 'Daniel Medina',
#   'date': '2024-09-18'},
#  22: {'title': 'Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.',
#   'keywords': {'bicicletas',
#    'compartidas',
#    'movilidad',
#    'sostenible',
#    'transporte',
#    'universidades'},
#   'author': 'Patricia Reyes',
#   'date': '2024-10-05'},
#  23: {'title': 'Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.',
#   'keywords': {'académica',
#    'apoyo',
#    'carga',
#    'emocional',
#    'estudiantes',
#    'salud',
#    'universitario'},
#   'author': 'Gonzalo Soto',
#   'date': '2024-11-12'},
#  24: {'title': 'Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.',
#   'keywords': {'académica',
#    'equilibrio',
#    'estrategias',
#    'estudiantes',
#    'social',
#    'vida'},
#   'author': 'Camila Aguilar',
#   'date': '2024-12-01'},
#  25: {'title': 'La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.',
#   'keywords': {'actividades',
#    'artísticas',
#    'bienestar',
#    'creatividad',
#    'psicológico',
#    'universitaria',
#    'vida'},
#   'author': 'Adrián Vargas',
#   'date': '2025-01-10'},
#  26: {'title': 'Los beneficios de los programas de becas para la retención de estudiantes en universidades.',
#   'keywords': {'becas',
#    'beneficios',
#    'de',
#    'estudiantes',
#    'programas',
#    'retención',
#    'universidades'},
#   'author': 'Teresa Romero',
#   'date': '2025-02-15'},
#  27: {'title': 'El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.',
#   'keywords': {'actividad',
#    'deportes',
#    'estudiantes',
#    'física',
#    'integración',
#    'social'},
#   'author': 'Alberto Peña',
#   'date': '2025-03-05'},
#  28: {'title': 'Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.',
#   'keywords': {'bienestar',
#    'de',
#    'del',
#    'estrés',
#    'eventos',
#    'reducción',
#    'talleres',
#    'universidad'},
#   'author': 'Silvia Campos',
#   'date': '2025-04-20'},
#  29: {'title': 'Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.',
#   'keywords': {'análisis',
#    'de',
#    'en',
#    'estudiantes',
#    'exámenes',
#    'hábitos',
#    'rendimiento',
#    'sueño'},
#   'author': 'Óscar Luna',
#   'date': '2025-05-15'},
#  30: {'title': 'Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.',
#   'keywords': {'artificial',
#    'comunidades',
#    'inteligencia',
#    'médicos',
#    'remotas',
#    'servicios',
#    'tecnología'},
#   'author': 'María Paredes',
#   'date': '2025-06-10'}}

# %% [markdown]
# ## Caclculo de relevancia

# %%
query_keywords = {qid: process_text(query) for qid, query in queries.items()}

# %%
document_texts = [" ".join(doc['keywords']) for doc in corpus.values()]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
# Vectorizar documentos y consultas usando TF-IDF
vectorizer = TfidfVectorizer()
doc_vectors = vectorizer.fit_transform(document_texts)
query_vectors = vectorizer.transform([" ".join(query) for query in query_keywords.values()])

# %%
# Función para calcular similitud de Jaccard
def jaccard_similarity(set1, set2):
    intersection = set1.intersection(set2)
    union = set1.union(set2)
    return len(intersection) / len(union) if union else 0

# %%
# Calcular relevancia y similitud entre cada consulta y documento
relevance_scores = {}
for qid, query_vector in enumerate(query_vectors):
    cos_sim = cosine_similarity(doc_vectors, query_vector).flatten()
    jaccard_sim = [jaccard_similarity(corpus[doc_id]['keywords'], query_keywords[qid + 1]) for doc_id in corpus]
    relevance_scores[qid + 1] = {
        doc_id: (cos_sim[idx], jaccard_sim[idx])
        for idx, doc_id in enumerate(corpus)
    }

# %% [markdown]
# ## Ranking de Documentos

# %%
# Ordenar documentos según la relevancia para cada consulta
ranked_results = {}
for qid, scores in relevance_scores.items():
    ranked_results[qid] = sorted(scores.items(), key=lambda x: (x[1][0], x[1][1]), reverse=True)

# Mostrar el ranking de documentos para cada consulta
for qid, ranking in ranked_results.items():
    print(f"\nRanking de documentos para la consulta {qid}: '{queries[qid]}'")
    for doc_id, (cos_score, jacc_score) in ranking:
        doc_info = corpus[doc_id]
        print(f"  Documento ID {doc_id} - Título: {doc_info['title']}")
        print(f"    Similitud Coseno: {cos_score:.4f}")
        print(f"    Similitud Jaccard: {jacc_score:.4f}")
# Out:
# Ranking de documentos para la consulta 1: 'Impacto de la salud mental en el rendimiento académico de los estudiantes universitarios'
#   Documento ID 7 - Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.6145
#     Similitud Jaccard: 0.3846
#   Documento ID 2 - Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.5484
#     Similitud Jaccard: 0.3846
#   Documento ID 14 - Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.4610
#     Similitud Jaccard: 0.3571
#   Documento ID 29 - Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.4082
#     Similitud Jaccard: 0.2500
#   Documento ID 13 - Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.3707
#     Similitud Jaccard: 0.3125
#   Documento ID 11 - Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.3643
#     Similitud Jaccard: 0.2857
#   Documento ID 19 - Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.2682
#     Similitud Jaccard: 0.2500
#   Documento ID 21 - Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.2531
#     Similitud Jaccard: 0.1176
#   Documento ID 18 - Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.2517
#     Similitud Jaccard: 0.1875
#   Documento ID 12 - Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.1381
#     Similitud Jaccard: 0.1333
#   Documento ID 23 - Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.1232
#     Similitud Jaccard: 0.1176
#   Documento ID 26 - Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.1056
#     Similitud Jaccard: 0.1176
#   Documento ID 1 - Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.0819
#     Similitud Jaccard: 0.0588
#   Documento ID 17 - Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.0720
#     Similitud Jaccard: 0.0588
#   Documento ID 9 - Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.0681
#     Similitud Jaccard: 0.0556
#   Documento ID 16 - Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.0650
#     Similitud Jaccard: 0.0556
#   Documento ID 28 - Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.0647
#     Similitud Jaccard: 0.0526
#   Documento ID 8 - Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.0443
#     Similitud Jaccard: 0.0588
#   Documento ID 15 - Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.0435
#     Similitud Jaccard: 0.0588
#   Documento ID 6 - Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.0411
#     Similitud Jaccard: 0.0588
#   Documento ID 24 - Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.0396
#     Similitud Jaccard: 0.0588
#   Documento ID 27 - Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.0379
#     Similitud Jaccard: 0.0588
#   Documento ID 20 - Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.0369
#     Similitud Jaccard: 0.0556
#   Documento ID 3 - Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 4 - Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 5 - Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 10 - Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 22 - Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 25 - Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 30 - Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#
# Ranking de documentos para la consulta 2: 'Actividades extracurriculares y bienestar emocional en el campus universitario'
#   Documento ID 15 - Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.6520
#     Similitud Jaccard: 0.3636
#   Documento ID 23 - Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.2984
#     Similitud Jaccard: 0.1429
#   Documento ID 5 - Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.2854
#     Similitud Jaccard: 0.1538
#   Documento ID 8 - Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.2466
#     Similitud Jaccard: 0.1538
#   Documento ID 25 - Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.2188
#     Similitud Jaccard: 0.1429
#   Documento ID 3 - Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.2087
#     Similitud Jaccard: 0.1538
#   Documento ID 29 - Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.1860
#     Similitud Jaccard: 0.0625
#   Documento ID 17 - Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.1285
#     Similitud Jaccard: 0.0714
#   Documento ID 6 - Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.0855
#     Similitud Jaccard: 0.0714
#   Documento ID 18 - Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.0802
#     Similitud Jaccard: 0.0667
#   Documento ID 28 - Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.0690
#     Similitud Jaccard: 0.0625
#   Documento ID 1 - Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 2 - Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 4 - Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 7 - Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 9 - Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 10 - Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 11 - Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 12 - Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 13 - Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 14 - Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 16 - Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 19 - Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 20 - Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 21 - Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 22 - Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 24 - Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 26 - Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 27 - Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 30 - Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#
# Ranking de documentos para la consulta 3: 'Estrategias universitarias para reducir el estrés en estudiantes'
#   Documento ID 24 - Título: Estrategias para equilibrar vida social y académica en estudiantes de universidades intensivas.
#     Similitud Coseno: 0.2894
#     Similitud Jaccard: 0.1667
#   Documento ID 29 - Título: Análisis de los hábitos de sueño y su relación con el rendimiento en exámenes universitarios.
#     Similitud Coseno: 0.2587
#     Similitud Jaccard: 0.1429
#   Documento ID 11 - Título: Impacto de la práctica regular de ejercicio en la reducción del estrés académico en estudiantes universitarios.
#     Similitud Coseno: 0.2460
#     Similitud Jaccard: 0.1667
#   Documento ID 4 - Título: El rol de las bibliotecas universitarias en el fomento de la investigación académica.
#     Similitud Coseno: 0.2280
#     Similitud Jaccard: 0.0833
#   Documento ID 5 - Título: Cómo los espacios verdes en los campus universitarios pueden mejorar la concentración y reducir el estrés.
#     Similitud Coseno: 0.1526
#     Similitud Jaccard: 0.0769
#   Documento ID 28 - Título: Cómo los eventos y talleres de bienestar organizados por la universidad ayudan a reducir el estrés.
#     Similitud Coseno: 0.1358
#     Similitud Jaccard: 0.0667
#   Documento ID 2 - Título: Cómo la nutrición balanceada afecta el rendimiento académico y la salud mental en estudiantes.
#     Similitud Coseno: 0.0525
#     Similitud Jaccard: 0.0769
#   Documento ID 8 - Título: La influencia del apoyo familiar y social en el bienestar emocional de los estudiantes universitarios.
#     Similitud Coseno: 0.0501
#     Similitud Jaccard: 0.0769
#   Documento ID 12 - Título: El papel del mindfulness y la meditación en la reducción de la ansiedad en estudiantes universitarios.
#     Similitud Coseno: 0.0493
#     Similitud Jaccard: 0.0833
#   Documento ID 15 - Título: Beneficios de las actividades extracurriculares para el bienestar emocional y social de los estudiantes.
#     Similitud Coseno: 0.0492
#     Similitud Jaccard: 0.0769
#   Documento ID 14 - Título: Cómo el acceso a servicios de salud mental en la universidad puede mejorar el desempeño académico.
#     Similitud Coseno: 0.0480
#     Similitud Jaccard: 0.0714
#   Documento ID 6 - Título: La influencia de la cultura universitaria en los hábitos saludables y el bienestar de los estudiantes.
#     Similitud Coseno: 0.0465
#     Similitud Jaccard: 0.0769
#   Documento ID 23 - Título: Cómo la carga de trabajo académico afecta la salud emocional de los estudiantes y qué pueden hacer las universidades para ayudar.
#     Similitud Coseno: 0.0440
#     Similitud Jaccard: 0.0714
#   Documento ID 18 - Título: Diferencias en el bienestar académico entre estudiantes que trabajan y aquellos que solo estudian.
#     Similitud Coseno: 0.0436
#     Similitud Jaccard: 0.0714
#   Documento ID 27 - Título: El rol de los deportes y la actividad física en la integración social y emocional de los estudiantes.
#     Similitud Coseno: 0.0428
#     Similitud Jaccard: 0.0769
#   Documento ID 20 - Título: El impacto de la tecnología y el uso de redes sociales en la calidad del sueño en estudiantes.
#     Similitud Coseno: 0.0417
#     Similitud Jaccard: 0.0714
#   Documento ID 26 - Título: Los beneficios de los programas de becas para la retención de estudiantes en universidades.
#     Similitud Coseno: 0.0404
#     Similitud Jaccard: 0.0714
#   Documento ID 13 - Título: Estrategias para mejorar la salud mental en estudiantes universitarios: el rol del apoyo psicológico y los grupos de estudio en el campus.
#     Similitud Coseno: 0.0403
#     Similitud Jaccard: 0.0625
#   Documento ID 19 - Título: Factores de riesgo y estrategias para prevenir el agotamiento académico en estudiantes universitarios.
#     Similitud Coseno: 0.0403
#     Similitud Jaccard: 0.0667
#   Documento ID 1 - Título: El aumento de la telemedicina para el tratamiento de condiciones de salud crónicas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 3 - Título: Estudio sobre cómo las relaciones de amistad contribuyen al bienestar de los estudiantes en el campus.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 7 - Título: La importancia del sueño en la salud mental y el rendimiento académico en jóvenes universitarios.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 9 - Título: El impacto de los hábitos de lectura en el desarrollo cognitivo en jóvenes y adultos.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 10 - Título: Avances en la tecnología para la medicina preventiva y su aplicación en jóvenes.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 16 - Título: El papel de los laboratorios de innovación educativa en el desarrollo de competencias tecnológicas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 17 - Título: Tendencias actuales en el diseño de campus para fomentar la interacción y colaboración.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 21 - Título: Investigación sobre el impacto de las tecnologías verdes en los edificios de las universidades.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 22 - Título: Estudio sobre el uso de bicicletas compartidas en universidades para mejorar la movilidad.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 25 - Título: La relación entre actividades artísticas y el bienestar psicológico en la vida universitaria.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
#   Documento ID 30 - Título: Cómo la inteligencia artificial está mejorando el acceso a servicios médicos en comunidades remotas.
#     Similitud Coseno: 0.0000
#     Similitud Jaccard: 0.0000
